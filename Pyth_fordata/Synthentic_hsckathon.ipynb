# %%
#Loading libraries
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib as plt

# %%
# reading in data
synth_data=pd.read_csv("/Users/wgatua/Downloads/Diabetes-Machine-Learning-Data/data/synthetic_data.csv")

# %%
synth_data.head()
# Out:
#         race  gender      age  time_in_hospital  num_lab_procedures  \
# 0  Caucasian  Female  [60-70)                 3                  40
# 1  Caucasian    Male  [50-60)                 5                  40
# 2  Caucasian  Female  [50-60)                 1                  43
# 3  Caucasian  Female  [70-80)                 1                  41
# 4  Caucasian  Female  [80-90)                 4                  68
#
#    num_procedures  num_medications  number_outpatient  number_emergency  \
# 0               0               14                  0                 1
# 1               0                5                  0                 0
# 2               0               23                  0                 0
# 3               5               14                  0                12
# 4               2               17                  0                 0
#
#    number_inpatient  ...  glipizide-metformin glimepiride-pioglitazone  \
# ...
